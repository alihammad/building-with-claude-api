# %%
# %pip install anthropic python-dotenv
# Out:
# Requirement already satisfied: anthropic in /home/ali/projects/building-with-claude-api/.venv/lib/python3.14/site-packages (0.121.0)
# Requirement already satisfied: python-dotenv in /home/ali/projects/building-with-claude-api/.venv/lib/python3.14/site-packages (1.2.2)
# Requirement already satisfied: anyio<5,>=3.5.0 in /home/ali/projects/building-with-claude-api/.venv/lib/python3.14/site-packages (from anthropic) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /home/ali/projects/building-with-claude-api/.venv/lib/python3.14/site-packages (from anthropic) (1.9.0)
# Requirement already satisfied: docstring-parser<1,>=0.15 in /home/ali/projects/building-with-claude-api/.venv/lib/python3.14/site-packages (from anthropic) (0.18.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /home/ali/projects/building-with-claude-api/.venv/lib/python3.14/site-packages (from anthropic) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /home/ali/projects/building-with-claude-api/.venv/lib/python3.14/site-packages (from anthropic) (0.16.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /home/ali/projects/building-with-claude-api/.venv/lib/python3.14/site-packages (from anthropic) (2.13.4)
# Requirement already satisfied: sniffio<2,>=1 in /home/ali/projects/building-with-claude-api/.venv/lib/python3.14/site-packages (from anthropic) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /home/ali/projects/building-with-claude-api/.venv/lib/python3.14/site-packages (from anthropic) (4.16.0)
# Requirement already satisfied: idna>=2.8 in /home/ali/projects/building-with-claude-api/.venv/lib/python3.14/site-packages (from anyio<5,>=3.5.0->anthropic) (3.18)
# Requirement already satisfied: certifi in /home/ali/projects/building-with-claude-api/.venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->anthropic) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /home/ali/projects/building-with-claude-api/.venv/lib/python3.14/site-packages (from httpx<1,>=0.25.0->anthropic) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /home/ali/projects/building-with-claude-api/.venv/lib/python3.14/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /home/ali/projects/building-with-claude-api/.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /home/ali/projects/building-with-claude-api/.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /home/ali/projects/building-with-claude-api/.venv/lib/python3.14/site-packages (from pydantic<3,>=1.9.0->anthropic) (0.4.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from dotenv import load_dotenv

load_dotenv()  # Load environment variables from .env file
# Out:
# True

# %%
from anthropic import Anthropic

client = Anthropic()
model = "claude-sonnet-4-6"

# %%
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

# %%
def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

# %%
def chat(messages):
    response = client.messages.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    return response.content[0].text

# %%
# add in the initial user question
messages = []
add_user_message(messages, "what is quantum computing?")

answer = chat(messages)

# print(answer)

# take the answer and add it to the conversation
add_assistant_message(messages, answer)

# add a follow up question
add_user_message(messages, "can you explain it in simpler terms?")

answer = chat(messages)

print(answer)
# Out:
# # Quantum Computing - Simply Explained
#
# ## Think of it like this:
#
# ### Regular Computer (What you use now)
# Imagine flipping a coin
# - It's either **heads** or **tails**
# - One answer at a time
# - This is like a regular computer bit: **0 or 1**
#
# ### Quantum Computer
# Now imagine the coin **while it's spinning in the air**
# - It's kind of **both heads AND tails** at the same time
# - Only when it lands do you get one answer
# - This is what a **qubit** does!
#
# ---
#
# ## So What's the Big Deal?
#
# Imagine solving a **maze**
#
# - 🖥️ A **regular computer** tries every path **one by one**
# - ⚛️ A **quantum computer** can try **all paths at the same time**
#
# This makes it **incredibly fast** for certain problems
#
# ---
#
# ## What Can It Do?
# - 💊 Help **discover new medicines**
# - 🔐 **Break or create** better security/passwords
# - 🌍 Solve complex **climate problems**
# - 🤖 Improve **artificial intelligence**
#
# ---
#
# ## The Catch
# - It's **very hard to build**
# - Very **expensive**
# - Still not ready for everyday use
#
# ---
#
# Think of quantum computing as a **super powerful calculator** that works in a completely different way than anything we've built before.
#
# Want to know anything else about it?

# %%
messages = []

while True:
    user_input = input("You: ")
    print(f"You: {user_input}")

    add_user_message(messages, user_input)
    answer = chat(messages)
    add_assistant_message(messages, answer)
    print("---")
    print(f"Assistant: {answer}")
    print("---")
# Out:
# You: 2+2
# ---
# Assistant: # Quantum Computing - Simply Explained
#
# ## The Simple Version
#
# Think of it like this:
#
# ### 🪙 Regular Computer = A Coin
# - A normal coin is either **heads or tails**
# - That's like a regular bit - either **0 or 1**
#
# ### 🌀 Quantum Computer = A Spinning Coin
# - While a coin is **spinning**, it's kind of **both heads AND tails** at the same time
# - That's a qubit in **superposition**
# - Only when it lands do you get a definite answer
#
# ---
#
# ## Why is that useful?
#
# Imagine searching through **1 million doors** to find a prize:
#
# - 🖥️ **Regular computer** = checks doors **one by one**
# - ⚛️ **Quantum computer** = checks **many doors at the same time**
#
# This makes it **incredibly faster** for certain problems
#
# ---
#
# ## The Catch
# - It's **very hard to build**
# - Qubits are extremely **fragile and sensitive**
# - Still mostly used by **scientists and researchers**
#
# ---
#
# ## One Sentence Summary
# > Quantum computers use the **weird rules of physics** to solve certain problems **much faster** than regular computers
#
# ---
#
# Also, **2 + 2 = 4** 😊
#
# Want to know anything else?
# ---
# You: add 4
# ---
# Assistant: **4 + 4 = 8** 😊
#
# (Taking the result of **2 + 2 = 4**, then adding **4** gives you **8**)
#
# Want to continue calculating or have any other questions?
# ---
# You:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[9], line 6
#       2     user_input = input("You: ")
#       3     print(f"You: {user_input}")
#       4
#       5     add_user_message(messages, user_input)
# ----> 6     answer = chat(messages)
#       7     add_assistant_message(messages, answer)
#       8     print("---")
#       9     print(f"Assistant: {answer}")
#
# Cell In[7], line 2, in chat(messages)
#       1 def chat(messages):
# ----> 2     response = client.messages.create(
#       3         model=model,
#       4         max_tokens=1000,
#       5         messages=messages,
#
# File ~/projects/building-with-claude-api/.venv/lib/python3.14/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# File ~/projects/building-with-claude-api/.venv/lib/python3.14/site-packages/anthropic/resources/messages/messages.py:1048, in Messages.create(self, max_tokens, messages, model, cache_control, container, inference_geo, metadata, output_config, service_tier, stop_sequences, stream, system, temperature, thinking, tool_choice, tools, top_k, top_p, user_profile_id, extra_headers, extra_query, extra_body, timeout)
#    1041     warnings.warn(
#    1042         f"Using Claude with {model} and 'thinking.type=enabled' is deprecated. Use 'thinking.type=adaptive' instead which results in better model performance in our testing: https://platform.claude.com/docs/en/build-with-claude/adaptive-thinking",
#    1043         UserWarning,
#    1044         stacklevel=3,
#    1045     )
#    1047 extra_headers = {**strip_not_given({"anthropic-user-profile-id": user_profile_id}), **(extra_headers or {})}
# -> 1048 return self._post(
#    1049     "/v1/messages",
#    1050     body=maybe_transform(
#    1051         {
#    1052             "max_tokens": max_tokens,
#    1053             "messages": messages,
#    1054             "model": model,
#    1055             "cache_control": cache_control,
#    1056             "container": container,
#    1057             "inference_geo": inference_geo,
#    1058             "metadata": metadata,
#    1059             "output_config": output_config,
#    1060             "service_tier": service_tier,
#    1061             "stop_sequences": stop_sequences,
#    1062             "stream": stream,
#    1063             "system": system,
#    1064             "temperature": temperature,
#    1065             "thinking": thinking,
#    1066             "tool_choice": tool_choice,
#    1067             "tools": tools,
#    1068             "top_k": top_k,
#    1069             "top_p": top_p,
#    1070         },
#    1071         message_create_params.MessageCreateParamsStreaming
#    1072         if stream
#    1073         else message_create_params.MessageCreateParamsNonStreaming,
#    1074     ),
#    1075     options=make_request_options(
#    1076         extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1077     ),
#    1078     cast_to=Message,
#    1079     stream=stream or False,
#    1080     stream_cls=Stream[RawMessageStreamEvent],
#    1081 )
#
# File ~/projects/building-with-claude-api/.venv/lib/python3.14/site-packages/anthropic/_base_client.py:1536, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1527     warnings.warn(
#    1528         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1529         "Please pass raw bytes via the `content` parameter instead.",
#    1530         DeprecationWarning,
#    1531         stacklevel=2,
#    1532     )
#    1533 opts = FinalRequestOptions.construct(
#    1534     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1535 )
# -> 1536 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~/projects/building-with-claude-api/.venv/lib/python3.14/site-packages/anthropic/_base_client.py:1195, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1192     if not response.is_closed:
#    1193         response.read()
# -> 1195     raise self._make_status_error_from_response(response) from None
#    1197 raise RuntimeError("could not resolve response (should never happen)")
#
# BadRequestError: Error code: 400 - {'type': 'error', 'error': {'type': 'invalid_request_error', 'message': 'messages.6: user messages must have non-empty content'}, 'request_id': 'req_011CdtX8b5v2dBXw688kMbHf'}
